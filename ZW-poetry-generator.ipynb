# %% [markdown]
# # Implementations of early and well-known poetry generators
#
# By [Allison Parrish](http://www.decontextualize.com/)
#
# This notebook had some Python implementations of a number of early and well-known poetry generators, including Knowles and Tenney's *A House of Dust*, Strachey's love letter generator and Nick Montfort's *Taroko Gorge*.

# %% [markdown]
# ## A House of Dust Modification
#
# Original written in Fortran in 1967 by Alison Knowles and James Tenney. [ELMCIP entry](https://elmcip.net/creative-work/house-dust). [More information](http://blog.calarts.edu/2009/09/10/alison-knowles-james-tenney-and-the-house-of-dust-at-calarts/). [Watch Alison Knowles read from this piece](https://www.youtube.com/watch?v=-68Z708lFsY).
#
# Edited by Zoe Wells using words found in Instagram ad transcription.

# %%
import random

# %%
filler = [
    ".",
    "_",
    "",
    "",
    ".of."
]

# %%
username = [
    "curology",
    "future",
    "yesterday",
    "encounters",
    "strange",
    "tattooer",
    "prose",
    "90s",
    "shop",
    "rise",
    "gold",
    "hair",
    "thewolf",
    "noble",
    "band",
    "wild",
    "alaska",
    "pizza",
    "movement",
    "company",
    "art",
    "beats4u",
    "peace",
    "factory",
    "newyork",
    "tiktok",
    "academy",
    "university",
    "fab",
    "nation",
    "site",
    "fit",
    "yas",
    "company",
    "official",
    "box"
    
]

# %%
imageType = [
    "image of ",
    "black and white photo of ",
    "illustration of ",
    "3 images of ",
    "looping video of ",
    "picture of "
]

# %%
subject = [
    "woman ",
    "man ",
    "women ",
    "men ",
    "people ",
    "silhouette ",
    "necklace ",
    "text ", 
    "wolf ",
    "tree ",
    "pizza ",
    "dancer ",
    "whale-like creature ",
    "empty house "
]

# %%
verb = [
    "with ",
    "holding ",
    "wearing ",
    "talking about ",
    "next to ",
    "in ",
    "on ",
    "washing ",
    "being carried by "
]

# %%
thing = [
    "bullhorn",
    "acne",
    "abstract line",
    "leaves",
    "tattoo of antlers",
    "hair",
    "neon multicolored box",
    "field of daisies",
    "public spaces",
    "martini glass",
    "psychedelic patterns",
    "live music & poetry",
    "jump rope",
    "tie-die shirt",
    "laptop",
    "sweat",
    "bikini",
    "easel and paints",
    "multicolored lines",   
]

# %%
links = [
    "Visit Instagram Profile > ",
    "Learn More > ",
    "Shop Now > "
]

# %%
captionA = [
    "So much ",
    "Clear, confident ",
    "We’re not ",
    "2018 was the year I challenged myself to be ",
    "spend time on your ",
    "where are ",
    "@",
    "Find curated ",
    "ATL GIRLS - ",
    "ranked top 5% in the World with ",
    "The world of humanity is possessed of two wings, ",
    "#",
    "self love is ",
    "Come out and see ",
    "Why ",
    "Stepping into the weekend in our ",
    "This is real: ",
    "$5 for ",
    "Start preparing for a career in ",
    "Discover- ",
    "Take a Sneak Peak inside ",
    "Stop ",
    "Subscribe to ",
    "Get ",
    "I feel confident and motivated in my ",
    "Need your "
    
]

# %%
captionB = [
    "labor",
    "pain",
    "stress",
    "hope",
    "skin",
    "history",
    "killer taxidermy artist",
    "hustle",
    "Leos",
    "14kt gold",
    "banker",
    "cool stuff",
    "sustainable and wild caught",
    "rolling auditions all month long",
    "arctic weather",
    "stairs",
    "Figure drawing sessions",
    "cancer nurses",
    "sister’s killer",
    "Free Shipping",
    "real power",
    "Bikini Body",
    "zits",
    "2% cash back" ,
    "playlist",
    "leggings",
    "NYU location abroad",
    "Money"
    
]

# %%
captionC = [
    " ",
    ". ",
    ", ",
    "! ",
    " ",
    ". ",
    ", ",
    "! ",
    "? ",
    "... ",
    "?! ",
    "!!! ",
    "- ",
    " and ",
    " in 2019. ",
    " & ",
    ", info in bio ~ ",
    " #tropical ",
    " #envy ",
    " [Shrugging Emoji] ",
    " for only $20/month ",
    " [Heart Eyes Emoji] ",
    " [Bicep Emoji] ",
    " [Matcha Emoji] ",
    " [Eye Emoji] "
    " today! "
]

# %%
stanza_count = 5
for i in range(stanza_count):
    brand = random.choice(username) + random.choice(filler) + random.choice(username)
    description = "[" + random.choice(imageType) + random.choice(subject) + random.choice(verb) + random.choice(thing) + "]"
    callToAction = random.choice(links)
    likenum = str(random.randint(2, 1000))
    
    if description.startswith("[l"):
        liketype = " Views"
        likenum = likenum*2
    else:
        liketype = " Likes"
    
    caption = random.choice(captionA) + random.choice(captionB) + random.choice(captionC)
    line = brand + ": " + caption
    
    while len(line) < 82:
        line = line + random.choice(captionA) + random.choice(captionB) + random.choice(captionC)   
    lineA = line[0:45]
    lineB = line[45:81]
    
    commentnum = str(random.randint(2, 100))
    
    print()
    print(brand)
    print("Sponsored")
    print(description)
    print(callToAction)
    print(likenum + liketype)
    print(lineA)
    print(lineB + " ... more")
    print("View " + commentnum + " comments")
# Out:
# hairtiktok
# Sponsored
# [black and white photo of women washing bikini]
# Visit Instagram Profile >
# 532 Likes
# hairtiktok: The world of humanity is possesse
# d of two wings, Money #tropical Stop ... more
# View 12 comments
#
# curologysite
# Sponsored
# [3 images of wolf washing tattoo of antlers]
# Learn More >
# 499 Likes
# curologysite: Discover- playlist [Matcha Emoj
# i] Why arctic weather [Shrugging Emo ... more
# View 12 comments
#
# hair.of.tattooer
# Sponsored
# [image of people being carried by bullhorn]
# Visit Instagram Profile >
# 512 Likes
# hair.of.tattooer: Subscribe to Figure drawing
#  sessions, info in bio ~ Stop hope i ... more
# View 100 comments
#
# pizzabox
# Sponsored
# [illustration of silhouette wearing field of daisies]
# Shop Now >
# 575 Likes
# pizzabox: Get skin #tropical Stop stairs [Mat
# cha Emoji] Discover- playlist! 2018  ... more
# View 97 comments
#
# nationband
# Sponsored
# [picture of whale-like creature wearing acne]
# Learn More >
# 438 Likes
# nationband: We’re not Money? So much real pow
# er?! Come out and see arctic weather ... more
# View 9 comments
